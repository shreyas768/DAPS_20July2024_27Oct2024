# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a DataFrame from Python Objects

# %%
np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CG','TN','AS','GJ']
mycols = ['Jan','Feb','Mar']

# %%
pd.DataFrame(data = mydata)
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
pd.DataFrame(data = mydata, index=myindex)
# Out:
#      0   1   2
# CG  95  11  81
# TN  70  63  87
# AS  75   9  77
# GJ  40   4  63

# %%
df = pd.DataFrame(data = mydata, index=myindex,columns=mycols)
df
# Out:
#     Jan  Feb  Mar
# CG   95   11   81
# TN   70   63   87
# AS   75    9   77
# GJ   40    4   63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CG to GJ
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %% [markdown]
# ## Reading a CSV file to DataFrame

# %%
df = pd.read_csv('tips.csv')

# %% [markdown]
# # Obtaining Basic Information about DataFrame

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.shape
# Out:
# (244, 11)

# %%
len(df)
# Out:
# 244

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %% [markdown]
# ### Selection and Indexing

# %%
#Grab a single column
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
#Grab multiple columns

df[['total_bill','sex','tip']]
# Out:
#      total_bill     sex   tip
# 0         16.99  Female  1.01
# 1         10.34    Male  1.66
# 2         21.01    Male  3.50
# 3         23.68    Male  3.31
# 4         24.59  Female  3.61
# ..          ...     ...   ...
# 239       29.03    Male  5.92
# 240       27.18  Female  2.00
# 241       22.67    Male  2.00
# 242       17.82    Male  1.75
# 243       18.78  Female  3.00
#
# [244 rows x 3 columns]

# %%
#Create a new column
df['tip_percentage'] = 100*df['tip']/df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %%
df['tip_per_person'] = df['tip']/df['size']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765
#
#    tip_per_person
# 0        0.505000
# 1        0.553333
# 2        1.166667
# 3        1.655000
# 4        0.902500

# %%
df['tip_percentage']=np.round(df['tip_percentage'],2)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68
#
#    tip_per_person
# 0        0.505000
# 1        0.553333
# 2        1.166667
# 3        1.655000
# 4        0.902500

# %%
df['bill_with_GST'] = 1.05*df['total_bill']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68
#
#    tip_per_person  bill_with_GST
# 0        0.505000        17.8395
# 1        0.553333        10.8570
# ...

# %%
#remove columns

df = df.drop('tip_per_person',axis=1)

# %%
df.head()  # or : df.drop('tip_per_person',axis=1, inplace= True)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68
#
#    bill_with_GST
# 0        17.8395
# 1        10.8570
# 2        22.0605
# 3        24.8640
# 4        25.8195

# %%
df3.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68
#
#    bill_with_GST
# 0        17.8395
# 1        10.8570
# 2        22.0605
# 3        24.8640
# 4        25.8195

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %%
x = df.drop('bill_with_GST',axis=1)

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
#
#    bill_with_GST
# 0        17.8395
# 1        10.8570

# %%
x.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05

# %%
df.drop(['tip','sex'],axis=1)
# Out:
#      total_bill smoker   day    time  size  price_per_person  \
# 0         16.99     No   Sun  Dinner     2              8.49
# 1         10.34     No   Sun  Dinner     3              3.45
# 2         21.01     No   Sun  Dinner     3              7.00
# 3         23.68     No   Sun  Dinner     2             11.84
# 4         24.59     No   Sun  Dinner     4              6.15
# ..          ...    ...   ...     ...   ...               ...
# 239       29.03     No   Sat  Dinner     3              9.68
# 240       27.18    Yes   Sat  Dinner     2             13.59
# 241       22.67    Yes   Sat  Dinner     2             11.34
# 242       17.82     No   Sat  Dinner     2              8.91
# 243       18.78     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage  \
# 0    Christy Cunningham  3560325168603410    Sun2959            5.94
# 1        Douglas Tucker  4478071379779230    Sun4608           16.05
# ...

# %%
#Index Basics

df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(1)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
#
#            Payer Name         CC Number Payment ID  tip_percentage  \
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
#
#    bill_with_GST
# 0        17.8395

# %%
df = df.set_index('Payment ID')
df.head(2)
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
#
#             tip_percentage  bill_with_GST
# Payment ID
# Sun2959               5.94        17.8395
# Sun4608              16.05        10.8570

# %%
df = df.reset_index()

# %%
df.columns
# Out:
# Index(['Payment ID', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size', 'price_per_person', 'Payer Name', 'CC Number', 'tip_percentage',
#        'bill_with_GST'],
#       dtype='object')

# %%
df = df[[ 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
       'size', 'price_per_person', 'Payer Name', 'CC Number', 'tip_percentage',
       'bill_with_GST','Payment ID']]
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number  tip_percentage  bill_with_GST  \
# 0  Christy Cunningham  3560325168603410            5.94        17.8395
# 1      Douglas Tucker  4478071379779230           16.05        10.8570
#
#   Payment ID
# 0    Sun2959
# 1    Sun4608

# %% [markdown]
# ## Rows

# %%
df = df.set_index('Payment ID')
df.head(2)
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
#
#             tip_percentage  bill_with_GST
# Payment ID
# Sun2959               5.94        17.8395
# Sun4608              16.05        10.8570

# %%
#name based
df.loc['Sun4608']
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# tip_percentage                 16.05
# bill_with_GST                 10.857
# Name: Sun4608, dtype: object

# %%
#Integer based
df.iloc[1]
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# tip_percentage                 16.05
# bill_with_GST                 10.857
# Name: Sun4608, dtype: object

# %%
#Multiple rows
df.iloc[100:105]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Fri4106          11.35  2.50  Female    Yes  Fri  Dinner     2
# Fri8382          15.38  3.00  Female    Yes  Fri  Dinner     2
# Sat6240          44.30  2.50  Female    Yes  Sat  Dinner     3
# Sat1015          22.42  3.48  Female    Yes  Sat  Dinner     2
# Sat3194          20.92  4.08  Female     No  Sat  Dinner     2
#
#             price_per_person           Payer Name         CC Number  \
# Payment ID
# Fri4106                 5.68           Lori Lynch    38558279384492
# Fri8382                 7.69        Tiffany Colon  6011012799432041
# Sat6240                14.77        Heather Cohen   379771118886604
# Sat1015                11.21     Kathleen Hawkins   348009865484721
# Sat3194                10.46  Gabrielle Frederick  4013010878990106
#
#             tip_percentage  bill_with_GST
# Payment ID
# Fri4106              22.03        11.9175
# Fri8382              19.51        16.1490
# ...

# %%
x1 = df.loc[['Fri4106','Sat6240','Fri8382']]

# %%
x1
# Out:
#             total_bill  tip     sex smoker  day    time  size  \
# Payment ID
# Fri4106          11.35  2.5  Female    Yes  Fri  Dinner     2
# Sat6240          44.30  2.5  Female    Yes  Sat  Dinner     3
# Fri8382          15.38  3.0  Female    Yes  Fri  Dinner     2
#
#             price_per_person     Payer Name         CC Number  tip_percentage  \
# Payment ID
# Fri4106                 5.68     Lori Lynch    38558279384492           22.03
# Sat6240                14.77  Heather Cohen   379771118886604            5.64
# Fri8382                 7.69  Tiffany Colon  6011012799432041           19.51
#
#             bill_with_GST
# Payment ID
# Fri4106           11.9175
# Sat6240           46.5150
# Fri8382           16.1490

# %%
df.loc[['Fri4106','Sat6240','Fri8382']]['Payer Name']
# Out:
# Payment ID
# Fri4106       Lori Lynch
# Sat6240    Heather Cohen
# Fri8382    Tiffany Colon
# Name: Payer Name, dtype: object

# %%
x1['Payer Name']
# Out:
# Payment ID
# Fri4106       Lori Lynch
# Sat6240    Heather Cohen
# Fri8382    Tiffany Colon
# Name: Payer Name, dtype: object

# %% [markdown]
# ## Remove Rows

# %%
df.drop('Fri8382',axis=0)  #inplace= True will delete said row permanently
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
#df.drop(0,axis=0)  #with named index, this will throw an error

# %%
#Insert a new row

one_row = df.iloc[0]
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# tip_percentage                    5.94
# bill_with_GST                  17.8395
# Name: Sun2959, dtype: object

# %%
type(one_row)
# Out:
# pandas.core.series.Series

# %%
df.tail()
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person       Payer Name         CC Number  \
# Payment ID
# Sat2657                 9.68    Michael Avila  5296068606052842
# Sat1766                13.59   Monica Sanders  3506806155565404
# Sat3880                11.34       Keith Wong  6011891618747196
# Sat17                   8.91     Dennis Dixon     4375220550950
# Thur672                 9.39  Michelle Hardin  3511451626698139
#
#             tip_percentage  bill_with_GST
# Payment ID
# Sat2657              20.39        30.4815
# Sat1766               7.36        28.5390
# ...

# %%
df.append(one_row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wl/v3x3g82n3b38s3cvwvtr0r7h0000gn/T/ipykernel_1553/1271293785.py in ?()
# ----> 1 df.append(one_row)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
pd.concat([df, pd.DataFrame([one_row])], ignore_index=False)
# Out:
#          total_bill   tip     sex smoker   day    time  size  \
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# ...             ...   ...     ...    ...   ...     ...   ...
# Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17         17.82  1.75    Male     No   Sat  Dinner     2
# Thur672       18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959       16.99  1.01  Female     No   Sun  Dinner     2
#
#          price_per_person          Payer Name         CC Number  \
# Sun2959              8.49  Christy Cunningham  3560325168603410
# Sun4608              3.45      Douglas Tucker  4478071379779230
# ...
